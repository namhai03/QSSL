# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# Change directory to the desired folder
os.chdir('/content/drive/MyDrive/Research/1. Nota_QSSL')
# Verify the current working directory
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Research/1. Nota_QSSL

# %%
! pip install pennylane
! pip install einops
# Out:
# Requirement already satisfied: pennylane in /usr/local/lib/python3.10/dist-packages (0.36.0)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Requirement already satisfied: rustworkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.15.1)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.6.12)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.3)
# Requirement already satisfied: pennylane-lightning>=0.36 in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.36.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.11.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.2.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)

# %%
import train
import eval
from random import randrange

device = 'cuda:0'
for _ in range(5):
    seed = randrange(200)
    _classifier = ['quantum']
    #_classifier = ['classical']
    _nlayers = [2,4,8,16]
    _gamma = [0.5]
    _data = ['MNIST','FashionMNIST','KMNIST']
    _k = [1,2,5,10]
    _c1 = [0]
    _c2 = [1]
    for classifier in _classifier:
        for data in _data:
            for nlayers in _nlayers:
                for gamma in _gamma:
                    for c1 in _c1:
                        for c2 in _c2:
                            print(classifier, nlayers, gamma, data, c1, c2)
                            train.main(seed, classifier, nlayers, gamma, data, c1, c2, device)
                            for k in _k:
                                print(classifier, nlayers, gamma, data, c1, c2, k)
                                eval.main(seed, classifier, nlayers, gamma, data, k, c1, c2, device)
# Out:
# quantum 2 0.5 MNIST 0 1
# CREATE MemoryBank: 5
# 5it [00:00,  6.91it/s]
# 5it [00:02,  1.98it/s]
# Epoch 0|Loss: 0.008776829577982426
# CREATE MemoryBank: 5
# 5it [00:00,  7.78it/s]
# 5it [00:03,  1.52it/s]
# Epoch 1|Loss: 0.006931775901466608
# CREATE MemoryBank: 5
# 5it [00:01,  4.59it/s]
# 5it [00:02,  1.89it/s]
# Epoch 2|Loss: 0.006971047725528479
# CREATE MemoryBank: 5
# 5it [00:00,  7.89it/s]
# 5it [00:02,  2.02it/s]
# Epoch 3|Loss: 0.01180009702220559
# CREATE MemoryBank: 5
# 5it [00:00,  7.82it/s]
# 5it [00:02,  2.04it/s]
# Epoch 4|Loss: 0.012339320592582225
# CREATE MemoryBank: 5
# 5it [00:00,  7.72it/s]
# 5it [00:03,  1.49it/s]
# Epoch 5|Loss: 0.009366642031818629
# CREATE MemoryBank: 5
# 5it [00:01,  4.88it/s]
# 5it [00:02,  2.03it/s]
# Epoch 6|Loss: 0.010216931812465191
# CREATE MemoryBank: 5
# 5it [00:00,  8.07it/s]
# 5it [00:02,  1.97it/s]
# Epoch 7|Loss: 0.011300189048051834
# CREATE MemoryBank: 5
# 5it [00:00,  7.69it/s]
# 5it [00:02,  2.01it/s]
# Epoch 8|Loss: 0.008228932041674852
# CREATE MemoryBank: 5
# 5it [00:00,  6.91it/s]
# 5it [00:03,  1.31it/s]
# Epoch 9|Loss: 0.011985871009528637
# CREATE MemoryBank: 5
# 5it [00:00,  6.20it/s]
# 5it [00:02,  2.00it/s]
# Epoch 10|Loss: 0.012109095975756646
# CREATE MemoryBank: 5
# 5it [00:00,  7.65it/s]
# 5it [00:02,  2.01it/s]
# Epoch 11|Loss: 0.011161500588059425
# CREATE MemoryBank: 5
# 5it [00:00,  7.76it/s]
# 5it [00:02,  2.04it/s]
# Epoch 12|Loss: 0.01101816277951002
# CREATE MemoryBank: 5
# 5it [00:00,  6.00it/s]
# 5it [00:03,  1.30it/s]
# Epoch 13|Loss: 0.013625691272318363
# CREATE MemoryBank: 5
# 5it [00:00,  6.56it/s]
# 5it [00:02,  2.03it/s]
# Epoch 14|Loss: 0.010483223292976619
# CREATE MemoryBank: 5
# 5it [00:00,  7.91it/s]
# 5it [00:02,  2.01it/s]
# Epoch 15|Loss: 0.00982356583699584
# CREATE MemoryBank: 5
# 5it [00:00,  7.72it/s]
# 5it [00:02,  1.99it/s]
# Epoch 16|Loss: 0.011859938129782676
# CREATE MemoryBank: 5
# 5it [00:00,  6.15it/s]
# 5it [00:03,  1.30it/s]
# Epoch 17|Loss: 0.010476692952215672
# CREATE MemoryBank: 5
# 5it [00:00,  6.72it/s]
# 5it [00:02,  1.99it/s]
# Epoch 18|Loss: 0.010795763693749905
# CREATE MemoryBank: 5
# 5it [00:00,  8.00it/s]
# 5it [00:02,  2.04it/s]
# Epoch 19|Loss: 0.012211495451629162
# CREATE MemoryBank: 5
# 5it [00:00,  7.95it/s]
# 5it [00:02,  2.02it/s]
# Epoch 20|Loss: 0.010769539885222912
# CREATE MemoryBank: 5
# 5it [00:00,  6.09it/s]
# 5it [00:03,  1.35it/s]
# Epoch 21|Loss: 0.011467016115784646
# CREATE MemoryBank: 5
# 5it [00:00,  6.43it/s]
# 5it [00:02,  2.01it/s]
# Epoch 22|Loss: 0.011001837998628616
# CREATE MemoryBank: 5
# 5it [00:00,  7.96it/s]
# 5it [00:02,  2.02it/s]
# Epoch 23|Loss: 0.012070444971323013
# CREATE MemoryBank: 5
# 5it [00:00,  6.80it/s]
# 5it [00:02,  2.00it/s]
# Epoch 24|Loss: 0.012402687594294548
# CREATE MemoryBank: 5
# 5it [00:00,  5.73it/s]
# 5it [00:03,  1.31it/s]
# Epoch 25|Loss: 0.01096005467697978
# CREATE MemoryBank: 5
# 5it [00:00,  6.79it/s]
# 5it [00:02,  2.01it/s]
# Epoch 26|Loss: 0.018400581553578377
# CREATE MemoryBank: 5
# 5it [00:00,  7.93it/s]
# 5it [00:02,  1.97it/s]
# Epoch 27|Loss: 0.011496815830469131
# CREATE MemoryBank: 5
# 5it [00:00,  7.85it/s]
# 5it [00:02,  2.05it/s]
# Epoch 28|Loss: 0.012982452288269997
# CREATE MemoryBank: 5
# 5it [00:00,  6.14it/s]
# 5it [00:03,  1.32it/s]
# Epoch 29|Loss: 0.01040488202124834
# CREATE MemoryBank: 5
# 5it [00:00,  6.96it/s]
# 5it [00:02,  2.03it/s]
# Epoch 30|Loss: 0.01494864970445633
# CREATE MemoryBank: 5
# 5it [00:00,  7.61it/s]
# 5it [00:02,  1.98it/s]
# Epoch 31|Loss: 0.011181959323585034
# CREATE MemoryBank: 5
# 5it [00:00,  7.77it/s]
# 5it [00:02,  1.94it/s]
# Epoch 32|Loss: 0.01629340201616287
# CREATE MemoryBank: 5
# 5it [00:00,  5.51it/s]
# 5it [00:03,  1.35it/s]
# Epoch 33|Loss: 0.010022558085620404
# CREATE MemoryBank: 5
# 5it [00:00,  6.87it/s]
# 5it [00:02,  2.00it/s]
# Epoch 34|Loss: 0.012107309978455305
# CREATE MemoryBank: 5
# 5it [00:00,  7.72it/s]
# 5it [00:02,  1.98it/s]
# Epoch 35|Loss: 0.01111418679356575
# CREATE MemoryBank: 5
# 5it [00:00,  7.81it/s]
# 5it [00:02,  2.04it/s]
# Epoch 36|Loss: 0.011216957867145539
# CREATE MemoryBank: 5
# 5it [00:00,  5.69it/s]
# 5it [00:03,  1.33it/s]
# Epoch 37|Loss: 0.010194613691419363
# CREATE MemoryBank: 5
# 5it [00:00,  6.97it/s]
# 5it [00:02,  2.02it/s]
# Epoch 38|Loss: 0.010619367472827435
# CREATE MemoryBank: 5
# 5it [00:00,  7.54it/s]
# 5it [00:02,  2.04it/s]
# Epoch 39|Loss: 0.013644396886229515
# CREATE MemoryBank: 5
# 5it [00:00,  7.51it/s]
# 5it [00:02,  1.96it/s]
# Epoch 40|Loss: 0.010064733400940894
# CREATE MemoryBank: 5
# 5it [00:00,  5.77it/s]
# 5it [00:03,  1.38it/s]
# Epoch 41|Loss: 0.01103562992066145
# CREATE MemoryBank: 5
# 5it [00:00,  6.95it/s]
# 5it [00:02,  1.99it/s]
# Epoch 42|Loss: 0.013241061009466648
# CREATE MemoryBank: 5
# 5it [00:00,  7.54it/s]
# 5it [00:02,  1.96it/s]
# Epoch 43|Loss: 0.01143030785024166
# CREATE MemoryBank: 5
# 5it [00:00,  7.86it/s]
# 5it [00:02,  2.03it/s]
# Epoch 44|Loss: 0.009847134165465832
# CREATE MemoryBank: 5
# 5it [00:00,  5.48it/s]
# 5it [00:03,  1.36it/s]
# Epoch 45|Loss: 0.010471692681312561
# CREATE MemoryBank: 5
# 5it [00:00,  6.83it/s]
# 5it [00:02,  1.83it/s]
# Epoch 46|Loss: 0.01182027030736208
# CREATE MemoryBank: 5
# 5it [00:00,  7.53it/s]
# 5it [00:02,  2.00it/s]
# Epoch 47|Loss: 0.010355635173618793
# CREATE MemoryBank: 5
# 5it [00:00,  7.58it/s]
# 5it [00:02,  1.93it/s]
# Epoch 48|Loss: 0.011052226833999156
# CREATE MemoryBank: 5
# 5it [00:00,  5.31it/s]
# 5it [00:03,  1.36it/s]
# Epoch 49|Loss: 0.010266842134296895
# CREATE MemoryBank: 5
# 5it [00:00,  6.33it/s]
# quantum 2 0.5 MNIST 0 1 1
# 12665
# tensor(0.0942, device='cuda:0')
# tensor(0.1895, device='cuda:0')
# tensor(0.2840, device='cuda:0')
# tensor(0.2929, device='cuda:0')
# quantum 2 0.5 MNIST 0 1 2
# 6332
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.1892, device='cuda:0')
# tensor(0.2955, device='cuda:0')
# quantum 2 0.5 MNIST 0 1 5
# 2533
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.2937, device='cuda:0')
# quantum 2 0.5 MNIST 0 1 10
# 1266
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.2804, device='cuda:0')
# quantum 4 0.5 MNIST 0 1
# CREATE MemoryBank: 5
# 5it [00:00,  6.77it/s]
# 5it [00:02,  1.74it/s]
# Epoch 0|Loss: 0.018150395900011062
# CREATE MemoryBank: 5
# 5it [00:00,  5.53it/s]
# 5it [00:04,  1.20it/s]
# Epoch 1|Loss: 0.01635976880788803
# CREATE MemoryBank: 5
# 5it [00:00,  7.21it/s]
# 5it [00:02,  1.72it/s]
# Epoch 2|Loss: 0.011159476265311241
# CREATE MemoryBank: 5
# 5it [00:00,  7.45it/s]
# 5it [00:02,  1.72it/s]
# Epoch 3|Loss: 0.010286150127649307
# CREATE MemoryBank: 5
# 5it [00:00,  6.92it/s]
# 5it [00:03,  1.31it/s]
# Epoch 4|Loss: 0.009596060216426849
# CREATE MemoryBank: 5
# 5it [00:01,  4.28it/s]
# 5it [00:03,  1.66it/s]
# Epoch 5|Loss: 0.009275569766759872
# CREATE MemoryBank: 5
# 5it [00:00,  6.88it/s]
# 5it [00:02,  1.69it/s]
# Epoch 6|Loss: 0.00886763809248805
# CREATE MemoryBank: 5
# 5it [00:00,  7.15it/s]
# 5it [00:03,  1.61it/s]
# Epoch 7|Loss: 0.009363735746592283
# CREATE MemoryBank: 5
# 5it [00:01,  4.36it/s]
# 5it [00:03,  1.28it/s]
# Epoch 8|Loss: 0.008172461669892073
# CREATE MemoryBank: 5
# 5it [00:00,  7.34it/s]
# 5it [00:02,  1.72it/s]
# Epoch 9|Loss: 0.007952842954546213
# CREATE MemoryBank: 5
# 5it [00:00,  6.80it/s]
# 5it [00:02,  1.73it/s]
# Epoch 10|Loss: 0.00926696415990591
# CREATE MemoryBank: 5
# 5it [00:00,  7.03it/s]
# 5it [00:04,  1.20it/s]
# Epoch 11|Loss: 0.011378343030810357
# CREATE MemoryBank: 5
# 5it [00:01,  2.73it/s]
# 5it [00:02,  1.69it/s]
# Epoch 12|Loss: 0.006996898725628853
# CREATE MemoryBank: 5
# 5it [00:00,  7.04it/s]
# 5it [00:02,  1.70it/s]
# Epoch 13|Loss: 0.008638368919491768
# CREATE MemoryBank: 5
# 5it [00:00,  6.91it/s]
# 5it [00:03,  1.27it/s]
# Epoch 14|Loss: 0.007702047657221556
# CREATE MemoryBank: 5
# 5it [00:00,  5.95it/s]
# 5it [00:02,  1.68it/s]
# Epoch 15|Loss: 0.007345930952578783
# CREATE MemoryBank: 5
# 5it [00:00,  6.81it/s]
# 5it [00:02,  1.70it/s]
# Epoch 16|Loss: 0.007781675830483436
# CREATE MemoryBank: 5
# 5it [00:00,  7.26it/s]
# 5it [00:03,  1.44it/s]
# Epoch 17|Loss: 0.00556454393081367
# CREATE MemoryBank: 5
# 5it [00:01,  4.12it/s]
# 5it [00:03,  1.31it/s]
# Epoch 18|Loss: 0.007602208014577627
# CREATE MemoryBank: 5
# 5it [00:00,  7.06it/s]
# 5it [00:02,  1.71it/s]
# Epoch 19|Loss: 0.00908923028036952
# CREATE MemoryBank: 5
# 5it [00:00,  7.16it/s]
# 5it [00:02,  1.72it/s]
# Epoch 20|Loss: 0.006776039022952318
# CREATE MemoryBank: 5
# 5it [00:00,  7.00it/s]
# 5it [00:04,  1.13it/s]
# Epoch 21|Loss: 0.006695176102221012
# CREATE MemoryBank: 5
# 5it [00:00,  7.13it/s]
# 5it [00:02,  1.71it/s]
# Epoch 22|Loss: 0.006577569060027599
# CREATE MemoryBank: 5
# 5it [00:00,  7.09it/s]
# 5it [00:02,  1.73it/s]
# Epoch 23|Loss: 0.008007705118507147
# CREATE MemoryBank: 5
# 5it [00:00,  6.96it/s]
# 5it [00:03,  1.37it/s]
# Epoch 24|Loss: 0.005881593376398086
# CREATE MemoryBank: 5
# 5it [00:01,  4.54it/s]
# 5it [00:03,  1.53it/s]
# Epoch 25|Loss: 0.0058394941501319405
# CREATE MemoryBank: 5
# 5it [00:00,  6.79it/s]
# 5it [00:02,  1.72it/s]
# Epoch 26|Loss: 0.005487697245553136
# CREATE MemoryBank: 5
# 5it [00:00,  6.68it/s]
# 5it [00:03,  1.63it/s]
# Epoch 27|Loss: 0.009955406654626131
# CREATE MemoryBank: 5
# 5it [00:01,  4.26it/s]
# 5it [00:04,  1.24it/s]
# Epoch 28|Loss: 0.007408536970615387
# CREATE MemoryBank: 5
# 5it [00:00,  6.83it/s]
# 5it [00:02,  1.67it/s]
# Epoch 29|Loss: 0.007250863406807184
# CREATE MemoryBank: 5
# 5it [00:00,  7.13it/s]
# 5it [00:02,  1.74it/s]
# Epoch 30|Loss: 0.006727272365242243
# CREATE MemoryBank: 5
# 5it [00:00,  7.26it/s]
# 5it [00:04,  1.25it/s]
# Epoch 31|Loss: 0.006370240263640881
# CREATE MemoryBank: 5
# 5it [00:00,  5.62it/s]
# 5it [00:02,  1.72it/s]
# Epoch 32|Loss: 0.007540129777044058
# CREATE MemoryBank: 5
# 5it [00:00,  6.86it/s]
# 5it [00:02,  1.71it/s]
# Epoch 33|Loss: 0.006318443454802036
# CREATE MemoryBank: 5
# 5it [00:00,  7.05it/s]
# 5it [00:03,  1.43it/s]
# Epoch 34|Loss: 0.007627651561051607
# CREATE MemoryBank: 5
# 5it [00:01,  4.38it/s]
# 5it [00:03,  1.36it/s]
# Epoch 35|Loss: 0.007680769916623831
# CREATE MemoryBank: 5
# 5it [00:00,  7.27it/s]
# 5it [00:02,  1.70it/s]
# Epoch 36|Loss: 0.009009294584393502
# CREATE MemoryBank: 5
# 5it [00:00,  7.08it/s]
# 5it [00:02,  1.72it/s]
# Epoch 37|Loss: 0.005994757730513811
# CREATE MemoryBank: 5
# 5it [00:00,  6.71it/s]
# 5it [00:04,  1.14it/s]
# Epoch 38|Loss: 0.00602049920707941
# CREATE MemoryBank: 5
# 5it [00:00,  5.94it/s]
# 5it [00:03,  1.66it/s]
# Epoch 39|Loss: 0.006002059113234282
# CREATE MemoryBank: 5
# 5it [00:00,  6.67it/s]
# 5it [00:02,  1.72it/s]
# Epoch 40|Loss: 0.005989233031868935
# CREATE MemoryBank: 5
# 5it [00:00,  6.89it/s]
# 5it [00:03,  1.42it/s]
# Epoch 41|Loss: 0.007556180423125625
# CREATE MemoryBank: 5
# 5it [00:01,  4.26it/s]
# 5it [00:03,  1.58it/s]
# Epoch 42|Loss: 0.006942771654576063
# CREATE MemoryBank: 5
# 5it [00:00,  7.04it/s]
# 5it [00:02,  1.71it/s]
# Epoch 43|Loss: 0.004735417524352669
# CREATE MemoryBank: 5
# 5it [00:00,  6.81it/s]
# 5it [00:03,  1.64it/s]
# Epoch 44|Loss: 0.005521061178296804
# CREATE MemoryBank: 5
# 5it [00:01,  4.43it/s]
# 5it [00:04,  1.19it/s]
# Epoch 45|Loss: 0.005956009356305003
# CREATE MemoryBank: 5
# 5it [00:00,  6.96it/s]
# 5it [00:02,  1.69it/s]
# Epoch 46|Loss: 0.004578420938923955
# CREATE MemoryBank: 5
# 5it [00:00,  6.83it/s]
# 5it [00:02,  1.70it/s]
# Epoch 47|Loss: 0.005899114068597555
# CREATE MemoryBank: 5
# 5it [00:00,  7.04it/s]
# 5it [00:04,  1.24it/s]
# Epoch 48|Loss: 0.005860194843262434
# CREATE MemoryBank: 5
# 5it [00:01,  4.99it/s]
# 5it [00:02,  1.72it/s]
# Epoch 49|Loss: 0.008630689792335033
# CREATE MemoryBank: 5
# 5it [00:00,  7.00it/s]
# quantum 4 0.5 MNIST 0 1 1
# 12665
# tensor(0.1880, device='cuda:0')
# tensor(0.3784, device='cuda:0')
# tensor(0.5702, device='cuda:0')
# tensor(0.5874, device='cuda:0')
# quantum 4 0.5 MNIST 0 1 2
# 6332
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.3822, device='cuda:0')
# tensor(0.5878, device='cuda:0')
# quantum 4 0.5 MNIST 0 1 5
# 2533
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5811, device='cuda:0')
# quantum 4 0.5 MNIST 0 1 10
# 1266
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5719, device='cuda:0')
# quantum 8 0.5 MNIST 0 1
# CREATE MemoryBank: 5
# 5it [00:01,  4.23it/s]
# 5it [00:05,  1.04s/it]
# Epoch 0|Loss: 0.005997691443189979
# CREATE MemoryBank: 5
# 5it [00:00,  6.04it/s]
# 5it [00:03,  1.31it/s]
# Epoch 1|Loss: 0.008972843643277884
# CREATE MemoryBank: 5
# 5it [00:00,  5.79it/s]
# 5it [00:03,  1.26it/s]
# Epoch 2|Loss: 0.0054871893487870695
# CREATE MemoryBank: 5
# 5it [00:01,  4.27it/s]
# 5it [00:05,  1.01s/it]
# Epoch 3|Loss: 0.00729085374623537
# CREATE MemoryBank: 5
# 5it [00:00,  5.81it/s]
# 5it [00:03,  1.34it/s]
# Epoch 4|Loss: 0.007034376263618469
# CREATE MemoryBank: 5
# 5it [00:00,  5.94it/s]
# 5it [00:04,  1.16it/s]
# Epoch 5|Loss: 0.0077773045748472215
# CREATE MemoryBank: 5
# 5it [00:01,  3.90it/s]
# 5it [00:04,  1.21it/s]
# Epoch 6|Loss: 0.0110197264701128
# CREATE MemoryBank: 5
# 5it [00:00,  5.16it/s]
# 5it [00:03,  1.32it/s]
# Epoch 7|Loss: 0.010140664875507355
# CREATE MemoryBank: 5
# 5it [00:00,  5.92it/s]
# 5it [00:05,  1.02s/it]
# Epoch 8|Loss: 0.0079281784594059
# CREATE MemoryBank: 5
# 5it [00:00,  5.16it/s]
# 5it [00:03,  1.33it/s]
# Epoch 9|Loss: 0.008408203069120646
# CREATE MemoryBank: 5
# 5it [00:00,  5.80it/s]
# 5it [00:03,  1.33it/s]
# Epoch 10|Loss: 0.010854711942374706
# CREATE MemoryBank: 5
# 5it [00:00,  5.41it/s]
# 5it [00:05,  1.06s/it]
# Epoch 11|Loss: 0.008159316703677177
# CREATE MemoryBank: 5
# 5it [00:00,  5.67it/s]
# 5it [00:03,  1.31it/s]
# Epoch 12|Loss: 0.008584376703947783
# CREATE MemoryBank: 5
# 5it [00:00,  5.69it/s]
# 5it [00:04,  1.21it/s]
# Epoch 13|Loss: 0.009558893460780381
# CREATE MemoryBank: 5
# 5it [00:01,  4.00it/s]
# 5it [00:04,  1.07it/s]
# Epoch 14|Loss: 0.011246009171009064
# CREATE MemoryBank: 5
# 5it [00:00,  5.88it/s]
# 5it [00:03,  1.32it/s]
# Epoch 15|Loss: 0.00863420320674777
# CREATE MemoryBank: 5
# 5it [00:00,  5.78it/s]
# 5it [00:04,  1.14it/s]
# Epoch 16|Loss: 0.006833827681839466
# CREATE MemoryBank: 5
# 5it [00:01,  4.27it/s]
# 5it [00:03,  1.30it/s]
# Epoch 17|Loss: 0.007165391650050879
# CREATE MemoryBank: 5
# 5it [00:00,  6.03it/s]
# 5it [00:03,  1.31it/s]
# Epoch 18|Loss: 0.007460486702620983
# CREATE MemoryBank: 5
# 5it [00:00,  5.76it/s]
# 5it [00:05,  1.06s/it]
# Epoch 19|Loss: 0.006650635413825512
# CREATE MemoryBank: 5
# 5it [00:00,  5.78it/s]
# 5it [00:03,  1.33it/s]
# Epoch 20|Loss: 0.00792528996244073
# CREATE MemoryBank: 5
# 5it [00:00,  5.92it/s]
# 5it [00:03,  1.31it/s]
# Epoch 21|Loss: 0.007853918801993131
# CREATE MemoryBank: 5
# 5it [00:01,  4.58it/s]
# 5it [00:05,  1.03s/it]
# Epoch 22|Loss: 0.006119638867676258
# CREATE MemoryBank: 5
# 5it [00:00,  5.82it/s]
# 5it [00:03,  1.30it/s]
# Epoch 23|Loss: 0.005749695468693972
# CREATE MemoryBank: 5
# 5it [00:00,  5.39it/s]
# 5it [00:04,  1.23it/s]
# Epoch 24|Loss: 0.007574566081166268
# CREATE MemoryBank: 5
# 5it [00:01,  4.19it/s]
# 5it [00:04,  1.05it/s]
# Epoch 25|Loss: 0.0076525362208485605
# CREATE MemoryBank: 5
# 5it [00:00,  5.71it/s]
# 5it [00:03,  1.31it/s]
# Epoch 26|Loss: 0.007743190508335829
# CREATE MemoryBank: 5
# 5it [00:00,  5.89it/s]
# 5it [00:04,  1.12it/s]
# Epoch 27|Loss: 0.0068120772019028665
# CREATE MemoryBank: 5
# 5it [00:01,  3.77it/s]
# 5it [00:03,  1.28it/s]
# Epoch 28|Loss: 0.007449250854551792
# CREATE MemoryBank: 5
# 5it [00:00,  5.60it/s]
# 5it [00:03,  1.31it/s]
# Epoch 29|Loss: 0.007084680814296007
# CREATE MemoryBank: 5
# 5it [00:00,  5.67it/s]
# 5it [00:05,  1.07s/it]
# Epoch 30|Loss: 0.007014078926295042
# CREATE MemoryBank: 5
# 5it [00:00,  5.96it/s]
# 5it [00:03,  1.32it/s]
# Epoch 31|Loss: 0.0065118297934532166
# CREATE MemoryBank: 5
# 5it [00:00,  5.70it/s]
# 5it [00:03,  1.31it/s]
# Epoch 32|Loss: 0.006119943782687187
# CREATE MemoryBank: 5
# 5it [00:01,  3.99it/s]
# 5it [00:04,  1.01it/s]
# Epoch 33|Loss: 0.006161985639482737
# CREATE MemoryBank: 5
# 5it [00:00,  5.84it/s]
# 5it [00:03,  1.32it/s]
# Epoch 34|Loss: 0.005403733067214489
# CREATE MemoryBank: 5
# 5it [00:00,  5.89it/s]
# 5it [00:04,  1.12it/s]
# Epoch 35|Loss: 0.004610497178509832
# CREATE MemoryBank: 5
# 5it [00:01,  3.90it/s]
# 5it [00:03,  1.25it/s]
# Epoch 36|Loss: 0.006392125459387899
# CREATE MemoryBank: 5
# 5it [00:00,  6.06it/s]
# 5it [00:03,  1.34it/s]
# Epoch 37|Loss: 0.004887545760720968
# CREATE MemoryBank: 5
# 5it [00:00,  5.81it/s]
# 5it [00:05,  1.04s/it]
# Epoch 38|Loss: 0.006765028554946184
# CREATE MemoryBank: 5
# 5it [00:00,  5.93it/s]
# 5it [00:03,  1.32it/s]
# Epoch 39|Loss: 0.004516441468149423
# CREATE MemoryBank: 5
# 5it [00:00,  5.65it/s]
# 5it [00:03,  1.32it/s]
# Epoch 40|Loss: 0.006302625173702836
# CREATE MemoryBank: 5
# 5it [00:01,  3.97it/s]
# 5it [00:05,  1.12s/it]
# Epoch 41|Loss: 0.008113750675693154
# CREATE MemoryBank: 5
# 5it [00:00,  5.76it/s]
# 5it [00:03,  1.32it/s]
# Epoch 42|Loss: 0.00547911087051034
# CREATE MemoryBank: 5
# 5it [00:00,  5.59it/s]
# 5it [00:04,  1.17it/s]
# Epoch 43|Loss: 0.0056074301712214945
# CREATE MemoryBank: 5
# 5it [00:01,  3.58it/s]
# 5it [00:04,  1.21it/s]
# Epoch 44|Loss: 0.006557311490178108
# CREATE MemoryBank: 5
# 5it [00:00,  5.69it/s]
# 5it [00:03,  1.33it/s]
# Epoch 45|Loss: 0.004456863552331924
# CREATE MemoryBank: 5
# 5it [00:00,  5.85it/s]
# 5it [00:05,  1.07s/it]
# Epoch 46|Loss: 0.007350054895505309
# CREATE MemoryBank: 5
# 5it [00:00,  5.90it/s]
# 5it [00:03,  1.31it/s]
# Epoch 47|Loss: 0.0058351954445242885
# CREATE MemoryBank: 5
# 5it [00:00,  5.92it/s]
# 5it [00:03,  1.32it/s]
# Epoch 48|Loss: 0.004317012010142207
# CREATE MemoryBank: 5
# 5it [00:01,  4.39it/s]
# 5it [00:05,  1.05s/it]
# Epoch 49|Loss: 0.004288994474336505
# CREATE MemoryBank: 5
# 5it [00:00,  5.68it/s]
# quantum 8 0.5 MNIST 0 1 1
# 12665
# tensor(0.1813, device='cuda:0')
# tensor(0.3637, device='cuda:0')
# tensor(0.5439, device='cuda:0')
# tensor(0.5610, device='cuda:0')
# quantum 8 0.5 MNIST 0 1 2
# 6332
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.3636, device='cuda:0')
# tensor(0.5621, device='cuda:0')
# quantum 8 0.5 MNIST 0 1 5
# 2533
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5681, device='cuda:0')
# quantum 8 0.5 MNIST 0 1 10
# 1266
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5766, device='cuda:0')
# quantum 16 0.5 MNIST 0 1
# CREATE MemoryBank: 5
# 5it [00:01,  4.52it/s]
# 5it [00:07,  1.41s/it]
# Epoch 0|Loss: 0.02833706811070442
# CREATE MemoryBank: 5
# 5it [00:01,  4.39it/s]
# 5it [00:05,  1.07s/it]
# Epoch 1|Loss: 0.0057633697986602785
# CREATE MemoryBank: 5
# 5it [00:01,  4.44it/s]
# 5it [00:06,  1.38s/it]
# Epoch 2|Loss: 0.0027798920404165984
# CREATE MemoryBank: 5
# 5it [00:01,  4.46it/s]
# 5it [00:05,  1.10s/it]
# Epoch 3|Loss: 0.006038121855817735
# CREATE MemoryBank: 5
# 5it [00:01,  4.45it/s]
# 5it [00:07,  1.40s/it]
# Epoch 4|Loss: 0.0035534561146050693
# CREATE MemoryBank: 5
# 5it [00:01,  4.37it/s]
# 5it [00:05,  1.08s/it]
# Epoch 5|Loss: 0.0030024326406419277
# CREATE MemoryBank: 5
# 5it [00:01,  4.48it/s]
# 5it [00:06,  1.39s/it]
# Epoch 6|Loss: 0.004815359460189938
# CREATE MemoryBank: 5
# 5it [00:01,  4.46it/s]
# 5it [00:05,  1.09s/it]
# Epoch 7|Loss: 0.007585630239918828
# CREATE MemoryBank: 5
# 5it [00:01,  4.29it/s]
# 5it [00:06,  1.39s/it]
# Epoch 8|Loss: 0.0032262605614960193
# CREATE MemoryBank: 5
# 5it [00:01,  4.34it/s]
# 5it [00:05,  1.09s/it]
# Epoch 9|Loss: 0.003221509093418717
# CREATE MemoryBank: 5
# 5it [00:01,  4.35it/s]
# 5it [00:07,  1.41s/it]
# Epoch 10|Loss: 0.0030109621584415436
# CREATE MemoryBank: 5
# 5it [00:01,  4.43it/s]
# 5it [00:05,  1.08s/it]
# Epoch 11|Loss: 0.005254720547236502
# CREATE MemoryBank: 5
# 5it [00:01,  4.39it/s]
# 5it [00:07,  1.40s/it]
# Epoch 12|Loss: 0.004621149692684412
# CREATE MemoryBank: 5
# 5it [00:01,  4.20it/s]
# 5it [00:05,  1.10s/it]
# Epoch 13|Loss: 0.004003414651378989
# CREATE MemoryBank: 5
# 5it [00:01,  3.84it/s]
# 5it [00:07,  1.41s/it]
# Epoch 14|Loss: 0.005468936450779438
# CREATE MemoryBank: 5
# 5it [00:01,  4.36it/s]
# 5it [00:05,  1.10s/it]
# Epoch 15|Loss: 0.0046723632141947745
# CREATE MemoryBank: 5
# 5it [00:01,  2.73it/s]
# 5it [00:06,  1.38s/it]
# Epoch 16|Loss: 0.003156781615689397
# CREATE MemoryBank: 5
# 5it [00:01,  4.42it/s]
# 5it [00:05,  1.10s/it]
# Epoch 17|Loss: 0.003495514066889882
# CREATE MemoryBank: 5
# 5it [00:01,  3.23it/s]
# 5it [00:06,  1.36s/it]
# Epoch 18|Loss: 0.002367046568542719
# CREATE MemoryBank: 5
# 5it [00:01,  4.28it/s]
# 5it [00:05,  1.12s/it]
# Epoch 19|Loss: 0.0025337659986689686
# CREATE MemoryBank: 5
# 5it [00:01,  2.98it/s]
# 5it [00:06,  1.35s/it]
# Epoch 20|Loss: 0.0018759793369099499
# CREATE MemoryBank: 5
# 5it [00:01,  4.40it/s]
# 5it [00:05,  1.14s/it]
# Epoch 21|Loss: 0.0034752309788018466
# CREATE MemoryBank: 5
# 5it [00:01,  2.93it/s]
# 5it [00:06,  1.30s/it]
# Epoch 22|Loss: 0.0018297255272045731
# CREATE MemoryBank: 5
# 5it [00:01,  4.30it/s]
# 5it [00:05,  1.13s/it]
# Epoch 23|Loss: 0.0023792615393176675
# CREATE MemoryBank: 5
# 5it [00:01,  3.00it/s]
# 5it [00:06,  1.34s/it]
# Epoch 24|Loss: 0.0015732362284325064
# CREATE MemoryBank: 5
# 5it [00:01,  4.37it/s]
# 5it [00:05,  1.16s/it]
# Epoch 25|Loss: 0.0020163007779046894
# CREATE MemoryBank: 5
# 5it [00:01,  2.88it/s]
# 5it [00:06,  1.33s/it]
# Epoch 26|Loss: 0.0018999323481693863
# CREATE MemoryBank: 5
# 5it [00:01,  4.26it/s]
# 5it [00:05,  1.17s/it]
# Epoch 27|Loss: 0.0016750470735132695
# CREATE MemoryBank: 5
# 5it [00:01,  3.03it/s]
# 5it [00:06,  1.32s/it]
# Epoch 28|Loss: 0.002414133748970926
# CREATE MemoryBank: 5
# 5it [00:01,  4.23it/s]
# 5it [00:05,  1.17s/it]
# Epoch 29|Loss: 0.001844788552261889
# CREATE MemoryBank: 5
# 5it [00:01,  2.90it/s]
# 5it [00:06,  1.28s/it]
# Epoch 30|Loss: 0.001979768555611372
# CREATE MemoryBank: 5
# 5it [00:01,  4.27it/s]
# 5it [00:06,  1.21s/it]
# Epoch 31|Loss: 0.0016028297715820373
# CREATE MemoryBank: 5
# 5it [00:01,  2.63it/s]
# 5it [00:05,  1.16s/it]
# Epoch 32|Loss: 0.0014672721037641168
# CREATE MemoryBank: 5
# 5it [00:01,  4.35it/s]
# 5it [00:06,  1.30s/it]
# Epoch 33|Loss: 0.004094173246994614
# CREATE MemoryBank: 5
# 5it [00:01,  3.58it/s]
# 5it [00:05,  1.11s/it]
# Epoch 34|Loss: 0.00373859996907413
# CREATE MemoryBank: 5
# 5it [00:01,  4.45it/s]
# 5it [00:07,  1.42s/it]
# Epoch 35|Loss: 0.002340570162050426
# CREATE MemoryBank: 5
# 5it [00:01,  4.07it/s]
# 5it [00:05,  1.10s/it]
# Epoch 36|Loss: 0.0025745654478669167
# CREATE MemoryBank: 5
# 5it [00:01,  3.08it/s]
# 5it [00:07,  1.42s/it]
# Epoch 37|Loss: 0.004171718144789338
# CREATE MemoryBank: 5
# 5it [00:01,  4.15it/s]
# 5it [00:05,  1.11s/it]
# Epoch 38|Loss: 0.002983851218596101
# CREATE MemoryBank: 5
# 5it [00:01,  4.39it/s]
# 5it [00:07,  1.45s/it]
# Epoch 39|Loss: 0.0018697823863476515
# CREATE MemoryBank: 5
# 5it [00:01,  4.27it/s]
# 5it [00:05,  1.11s/it]
# Epoch 40|Loss: 0.003262330126017332
# CREATE MemoryBank: 5
# 5it [00:01,  4.31it/s]
# 5it [00:07,  1.41s/it]
# Epoch 41|Loss: 0.002290380105841905
# CREATE MemoryBank: 5
# 5it [00:01,  4.20it/s]
# 5it [00:05,  1.12s/it]
# Epoch 42|Loss: 0.0022904329001903535
# CREATE MemoryBank: 5
# 5it [00:01,  3.73it/s]
# 5it [00:07,  1.43s/it]
# Epoch 43|Loss: 0.0019963380182161927
# CREATE MemoryBank: 5
# 5it [00:01,  4.35it/s]
# 5it [00:05,  1.12s/it]
# Epoch 44|Loss: 0.0015312663395889103
# CREATE MemoryBank: 5
# 5it [00:01,  3.28it/s]
# 5it [00:06,  1.38s/it]
# Epoch 45|Loss: 0.00166291348868981
# CREATE MemoryBank: 5
# 5it [00:01,  4.35it/s]
# 5it [00:05,  1.10s/it]
# Epoch 46|Loss: 0.0017690683947876097
# CREATE MemoryBank: 5
# 5it [00:01,  3.28it/s]
# 5it [00:06,  1.37s/it]
# Epoch 47|Loss: 0.003230154060292989
# CREATE MemoryBank: 5
# 5it [00:01,  4.40it/s]
# 5it [00:05,  1.15s/it]
# Epoch 48|Loss: 0.003532093903049827
# CREATE MemoryBank: 5
# 5it [00:01,  2.94it/s]
# 5it [00:06,  1.36s/it]
# Epoch 49|Loss: 0.0025418815086595712
# CREATE MemoryBank: 5
# 5it [00:01,  4.34it/s]
# quantum 16 0.5 MNIST 0 1 1
# 12665
# tensor(0.1428, device='cuda:0')
# tensor(0.2888, device='cuda:0')
# tensor(0.4348, device='cuda:0')
# tensor(0.4468, device='cuda:0')
# quantum 16 0.5 MNIST 0 1 2
# 6332
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.2942, device='cuda:0')
# tensor(0.4503, device='cuda:0')
# quantum 16 0.5 MNIST 0 1 5
# 2533
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.4485, device='cuda:0')
# quantum 16 0.5 MNIST 0 1 10
# 1266
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.4344, device='cuda:0')
# quantum 2 0.5 FashionMNIST 0 1
# CREATE MemoryBank: 4
# 4it [00:01,  3.94it/s]
# 4it [00:03,  1.31it/s]
# Epoch 0|Loss: 0.013662155019119382
# CREATE MemoryBank: 4
# 4it [00:00,  6.12it/s]
# 4it [00:02,  1.77it/s]
# Epoch 1|Loss: 0.010465656989254057
# CREATE MemoryBank: 4
# 4it [00:00,  6.41it/s]
# 4it [00:02,  1.78it/s]
# Epoch 2|Loss: 0.010284085292369127
# CREATE MemoryBank: 4
# 4it [00:00,  6.53it/s]
# 4it [00:02,  1.66it/s]
# Epoch 3|Loss: 0.009625162463635206
# CREATE MemoryBank: 4
# 4it [00:01,  3.99it/s]
# 4it [00:03,  1.17it/s]
# Epoch 4|Loss: 0.008290989557281137
# CREATE MemoryBank: 4
# 4it [00:00,  6.37it/s]
# 4it [00:02,  1.73it/s]
# Epoch 5|Loss: 0.009728318429552019
# CREATE MemoryBank: 4
# 4it [00:00,  6.36it/s]
# 4it [00:02,  1.76it/s]
# Epoch 6|Loss: 0.00833340419922024
# CREATE MemoryBank: 4
# 4it [00:00,  6.33it/s]
# 4it [00:02,  1.76it/s]
# Epoch 7|Loss: 0.010005895746871829
# CREATE MemoryBank: 4
# 4it [00:00,  5.30it/s]
# 4it [00:03,  1.12it/s]
# Epoch 8|Loss: 0.010476774768903852
# CREATE MemoryBank: 4
# 4it [00:00,  5.42it/s]
# 4it [00:02,  1.70it/s]
# Epoch 9|Loss: 0.011006375076249242
# CREATE MemoryBank: 4
# 4it [00:00,  6.29it/s]
# 4it [00:02,  1.76it/s]
# Epoch 10|Loss: 0.011701115756295621
# CREATE MemoryBank: 4
# 4it [00:00,  6.38it/s]
# 4it [00:02,  1.75it/s]
# Epoch 11|Loss: 0.015082298079505563
# CREATE MemoryBank: 4
# 4it [00:00,  6.26it/s]
# 4it [00:03,  1.23it/s]
# Epoch 12|Loss: 0.00894956081174314
# CREATE MemoryBank: 4
# 4it [00:01,  3.76it/s]
# 4it [00:02,  1.77it/s]
# Epoch 13|Loss: 0.01049777027219534
# CREATE MemoryBank: 4
# 4it [00:00,  6.28it/s]
# 4it [00:02,  1.71it/s]
# Epoch 14|Loss: 0.01389110751915723
# CREATE MemoryBank: 4
# 4it [00:00,  6.42it/s]
# 4it [00:02,  1.74it/s]
# Epoch 15|Loss: 0.0095091606490314
# CREATE MemoryBank: 4
# 4it [00:00,  6.38it/s]
# 4it [00:03,  1.33it/s]
# Epoch 16|Loss: 0.011757079046219587
# CREATE MemoryBank: 4
# 4it [00:00,  4.06it/s]
# 4it [00:02,  1.61it/s]
# Epoch 17|Loss: 0.008525764336809516
# CREATE MemoryBank: 4
# 4it [00:00,  6.33it/s]
# 4it [00:02,  1.73it/s]
# Epoch 18|Loss: 0.010314820799976587
# CREATE MemoryBank: 4
# 4it [00:00,  6.43it/s]
# 4it [00:02,  1.78it/s]
# Epoch 19|Loss: 0.01031140354461968
# CREATE MemoryBank: 4
# 4it [00:00,  6.18it/s]
# 4it [00:02,  1.38it/s]
# Epoch 20|Loss: 0.01002550614066422
# CREATE MemoryBank: 4
# 4it [00:00,  4.13it/s]
# 4it [00:02,  1.34it/s]
# Epoch 21|Loss: 0.010854047257453203
# CREATE MemoryBank: 4
# 4it [00:00,  6.58it/s]
# 4it [00:02,  1.80it/s]
# Epoch 22|Loss: 0.01039437996223569
# CREATE MemoryBank: 4
# 4it [00:00,  6.27it/s]
# 4it [00:02,  1.76it/s]
# Epoch 23|Loss: 0.008951700991019607
# CREATE MemoryBank: 4
# 4it [00:00,  6.38it/s]
# 4it [00:02,  1.69it/s]
# Epoch 24|Loss: 0.009220689302310348
# CREATE MemoryBank: 4
# 4it [00:00,  4.15it/s]
# 4it [00:03,  1.12it/s]
# Epoch 25|Loss: 0.012269365135580301
# CREATE MemoryBank: 4
# 4it [00:00,  6.16it/s]
# 4it [00:02,  1.74it/s]
# Epoch 26|Loss: 0.008617583313025534
# CREATE MemoryBank: 4
# 4it [00:00,  5.69it/s]
# 4it [00:02,  1.75it/s]
# Epoch 27|Loss: 0.0103922956623137
# CREATE MemoryBank: 4
# 4it [00:00,  6.40it/s]
# 4it [00:02,  1.75it/s]
# Epoch 28|Loss: 0.010112699936144054
# CREATE MemoryBank: 4
# 4it [00:00,  5.16it/s]
# 4it [00:03,  1.16it/s]
# Epoch 29|Loss: 0.01365738152526319
# CREATE MemoryBank: 4
# 4it [00:00,  5.44it/s]
# 4it [00:02,  1.76it/s]
# Epoch 30|Loss: 0.008930642856284976
# CREATE MemoryBank: 4
# 4it [00:00,  6.18it/s]
# 4it [00:02,  1.74it/s]
# Epoch 31|Loss: 0.01677065691910684
# CREATE MemoryBank: 4
# 4it [00:00,  6.03it/s]
# 4it [00:02,  1.75it/s]
# Epoch 32|Loss: 0.010054654907435179
# CREATE MemoryBank: 4
# 4it [00:00,  6.20it/s]
# 4it [00:03,  1.20it/s]
# Epoch 33|Loss: 0.008702472550794482
# CREATE MemoryBank: 4
# 4it [00:00,  5.08it/s]
# 4it [00:02,  1.73it/s]
# Epoch 34|Loss: 0.009969073929823935
# CREATE MemoryBank: 4
# 4it [00:00,  6.44it/s]
# 4it [00:02,  1.69it/s]
# Epoch 35|Loss: 0.009007408050820231
# CREATE MemoryBank: 4
# 4it [00:00,  5.47it/s]
# 4it [00:02,  1.75it/s]
# Epoch 36|Loss: 0.008240894763730466
# CREATE MemoryBank: 4
# 4it [00:00,  6.38it/s]
# 4it [00:03,  1.20it/s]
# Epoch 37|Loss: 0.00826552847865969
# CREATE MemoryBank: 4
# 4it [00:00,  4.39it/s]
# 4it [00:02,  1.72it/s]
# Epoch 38|Loss: 0.01101076090708375
# CREATE MemoryBank: 4
# 4it [00:00,  6.50it/s]
# 4it [00:02,  1.76it/s]
# Epoch 39|Loss: 0.012404340552166104
# CREATE MemoryBank: 4
# 4it [00:00,  6.43it/s]
# 4it [00:02,  1.76it/s]
# Epoch 40|Loss: 0.009571159491315484
# CREATE MemoryBank: 4
# 4it [00:00,  6.43it/s]
# 4it [00:03,  1.29it/s]
# Epoch 41|Loss: 0.009021983249112964
# CREATE MemoryBank: 4
# 4it [00:01,  3.72it/s]
# 4it [00:02,  1.65it/s]
# Epoch 42|Loss: 0.007984689786098897
# CREATE MemoryBank: 4
# 4it [00:00,  6.31it/s]
# 4it [00:02,  1.72it/s]
# Epoch 43|Loss: 0.009390481049194932
# CREATE MemoryBank: 4
# 4it [00:00,  6.37it/s]
# 4it [00:02,  1.71it/s]
# Epoch 44|Loss: 0.011312005808576941
# CREATE MemoryBank: 4
# 4it [00:00,  6.01it/s]
# 4it [00:02,  1.36it/s]
# Epoch 45|Loss: 0.010154541116207838
# CREATE MemoryBank: 4
# 4it [00:00,  4.01it/s]
# 4it [00:02,  1.55it/s]
# Epoch 46|Loss: 0.011182258022017777
# CREATE MemoryBank: 4
# 4it [00:00,  6.34it/s]
# 4it [00:02,  1.74it/s]
# Epoch 47|Loss: 0.011259833932854235
# CREATE MemoryBank: 4
# 4it [00:00,  6.32it/s]
# 4it [00:02,  1.75it/s]
# Epoch 48|Loss: 0.012904455186799169
# CREATE MemoryBank: 4
# 4it [00:00,  6.27it/s]
# 4it [00:02,  1.41it/s]
# Epoch 49|Loss: 0.008122838567942381
# CREATE MemoryBank: 4
# 4it [00:00,  4.30it/s]
# quantum 2 0.5 FashionMNIST 0 1 1
# 12000
# tensor(0.1933, device='cuda:0')
# tensor(0.3840, device='cuda:0')
# tensor(0.5615, device='cuda:0')
# quantum 2 0.5 FashionMNIST 0 1 2
# 6000
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.3882, device='cuda:0')
# tensor(0.5695, device='cuda:0')
# quantum 2 0.5 FashionMNIST 0 1 5
# 2400
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5588, device='cuda:0')
# quantum 2 0.5 FashionMNIST 0 1 10
# 1200
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5675, device='cuda:0')
# quantum 4 0.5 FashionMNIST 0 1
# CREATE MemoryBank: 4
# 4it [00:00,  5.68it/s]
# 4it [00:02,  1.53it/s]
# Epoch 0|Loss: 0.011976421577855945
# CREATE MemoryBank: 4
# 4it [00:00,  5.45it/s]
# 4it [00:03,  1.30it/s]
# Epoch 1|Loss: 0.007909808191470802
# CREATE MemoryBank: 4
# 4it [00:01,  3.64it/s]
# 4it [00:03,  1.12it/s]
# Epoch 2|Loss: 0.005408267839811742
# CREATE MemoryBank: 4
# 4it [00:00,  5.79it/s]
# 4it [00:02,  1.57it/s]
# Epoch 3|Loss: 0.010121391853317618
# CREATE MemoryBank: 4
# 4it [00:00,  5.96it/s]
# 4it [00:02,  1.44it/s]
# Epoch 4|Loss: 0.011215045815333724
# CREATE MemoryBank: 4
# 4it [00:00,  5.83it/s]
# 4it [00:03,  1.25it/s]
# Epoch 5|Loss: 0.010052352910861373
# CREATE MemoryBank: 4
# 4it [00:01,  3.97it/s]
# 4it [00:02,  1.36it/s]
# Epoch 6|Loss: 0.009125191252678633
# CREATE MemoryBank: 4
# 4it [00:00,  5.76it/s]
# 4it [00:02,  1.57it/s]
# Epoch 7|Loss: 0.008553914492949843
# CREATE MemoryBank: 4
# 4it [00:00,  5.96it/s]
# 4it [00:02,  1.52it/s]
# Epoch 8|Loss: 0.00866114383097738
# CREATE MemoryBank: 4
# 4it [00:00,  5.33it/s]
# 4it [00:03,  1.07it/s]
# Epoch 9|Loss: 0.009956898866221309
# CREATE MemoryBank: 4
# 4it [00:00,  4.96it/s]
# 4it [00:02,  1.56it/s]
# Epoch 10|Loss: 0.00988561031408608
# CREATE MemoryBank: 4
# 4it [00:00,  6.10it/s]
# 4it [00:02,  1.55it/s]
# Epoch 11|Loss: 0.0094151213997975
# CREATE MemoryBank: 4
# 4it [00:00,  5.92it/s]
# 4it [00:02,  1.54it/s]
# Epoch 12|Loss: 0.010504818055778742
# CREATE MemoryBank: 4
# 4it [00:01,  3.91it/s]
# 4it [00:03,  1.03it/s]
# Epoch 13|Loss: 0.013063113205134869
# CREATE MemoryBank: 4
# 4it [00:00,  5.40it/s]
# 4it [00:02,  1.54it/s]
# Epoch 14|Loss: 0.010447724955156446
# CREATE MemoryBank: 4
# 4it [00:00,  6.11it/s]
# 4it [00:02,  1.57it/s]
# Epoch 15|Loss: 0.00944836251437664
# CREATE MemoryBank: 4
# 4it [00:00,  5.83it/s]
# 4it [00:02,  1.46it/s]
# Epoch 16|Loss: 0.010746748186647892
# CREATE MemoryBank: 4
# 4it [00:01,  3.60it/s]
# 4it [00:03,  1.01it/s]
# Epoch 17|Loss: 0.007478054496459663
# CREATE MemoryBank: 4
# 4it [00:00,  5.98it/s]
# 4it [00:02,  1.50it/s]
# Epoch 18|Loss: 0.007965219439938664
# CREATE MemoryBank: 4
# 4it [00:00,  5.85it/s]
# 4it [00:02,  1.59it/s]
# Epoch 19|Loss: 0.012560292729176581
# CREATE MemoryBank: 4
# 4it [00:00,  5.65it/s]
# 4it [00:02,  1.37it/s]
# Epoch 20|Loss: 0.010593470418825746
# CREATE MemoryBank: 4
# 4it [00:00,  4.01it/s]
# 4it [00:03,  1.07it/s]
# Epoch 21|Loss: 0.011496393592096865
# CREATE MemoryBank: 4
# 4it [00:00,  6.03it/s]
# 4it [00:02,  1.53it/s]
# Epoch 22|Loss: 0.012518414296209812
# CREATE MemoryBank: 4
# 4it [00:00,  5.66it/s]
# 4it [00:02,  1.54it/s]
# Epoch 23|Loss: 0.007033792440779507
# CREATE MemoryBank: 4
# 4it [00:00,  5.81it/s]
# 4it [00:03,  1.29it/s]
# Epoch 24|Loss: 0.010045485571026802
# CREATE MemoryBank: 4
# 4it [00:01,  3.66it/s]
# 4it [00:03,  1.19it/s]
# Epoch 25|Loss: 0.006203953409567475
# CREATE MemoryBank: 4
# 4it [00:00,  6.05it/s]
# 4it [00:02,  1.55it/s]
# Epoch 26|Loss: 0.005637868540361524
# CREATE MemoryBank: 4
# 4it [00:00,  6.04it/s]
# 4it [00:02,  1.53it/s]
# Epoch 27|Loss: 0.006264538737013936
# CREATE MemoryBank: 4
# 4it [00:00,  5.77it/s]
# 4it [00:04,  1.14s/it]
# Epoch 28|Loss: 0.008146611391566694
# CREATE MemoryBank: 4
# 4it [00:00,  4.57it/s]
# 4it [00:02,  1.57it/s]
# Epoch 29|Loss: 0.006643151165917516
# CREATE MemoryBank: 4
# 4it [00:00,  5.66it/s]
# 4it [00:02,  1.56it/s]
# Epoch 30|Loss: 0.00461384211666882
# CREATE MemoryBank: 4
# 4it [00:00,  5.88it/s]
# 4it [00:02,  1.53it/s]
# Epoch 31|Loss: 0.005192419397644699
# CREATE MemoryBank: 4
# 4it [00:01,  3.86it/s]
# 4it [00:03,  1.02it/s]
# Epoch 32|Loss: 0.005382005241699517
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:02,  1.55it/s]
# Epoch 33|Loss: 0.007907826104201376
# CREATE MemoryBank: 4
# 4it [00:00,  5.82it/s]
# 4it [00:02,  1.59it/s]
# Epoch 34|Loss: 0.009354352951049805
# CREATE MemoryBank: 4
# 4it [00:00,  5.91it/s]
# 4it [00:02,  1.58it/s]
# Epoch 35|Loss: 0.007435563602484763
# CREATE MemoryBank: 4
# 4it [00:01,  3.97it/s]
# 4it [00:03,  1.03it/s]
# Epoch 36|Loss: 0.005511100578587502
# CREATE MemoryBank: 4
# 4it [00:00,  5.06it/s]
# 4it [00:02,  1.53it/s]
# Epoch 37|Loss: 0.006071827607229352
# CREATE MemoryBank: 4
# 4it [00:00,  5.63it/s]
# 4it [00:02,  1.54it/s]
# Epoch 38|Loss: 0.0065125704277306795
# CREATE MemoryBank: 4
# 4it [00:00,  5.56it/s]
# 4it [00:02,  1.44it/s]
# Epoch 39|Loss: 0.005426329211331904
# CREATE MemoryBank: 4
# 4it [00:01,  3.75it/s]
# 4it [00:03,  1.05it/s]
# Epoch 40|Loss: 0.0063666480127722025
# CREATE MemoryBank: 4
# 4it [00:00,  6.04it/s]
# 4it [00:02,  1.57it/s]
# Epoch 41|Loss: 0.0057708885869942605
# CREATE MemoryBank: 4
# 4it [00:00,  5.67it/s]
# 4it [00:02,  1.55it/s]
# Epoch 42|Loss: 0.006130195688456297
# CREATE MemoryBank: 4
# 4it [00:00,  5.74it/s]
# 4it [00:02,  1.41it/s]
# Epoch 43|Loss: 0.006359212566167116
# CREATE MemoryBank: 4
# 4it [00:01,  3.80it/s]
# 4it [00:03,  1.01it/s]
# Epoch 44|Loss: 0.006142288562841713
# CREATE MemoryBank: 4
# 4it [00:00,  5.61it/s]
# 4it [00:02,  1.56it/s]
# Epoch 45|Loss: 0.006968273199163377
# CREATE MemoryBank: 4
# 4it [00:00,  5.81it/s]
# 4it [00:02,  1.55it/s]
# Epoch 46|Loss: 0.005048324819654226
# CREATE MemoryBank: 4
# 4it [00:00,  6.03it/s]
# 4it [00:02,  1.35it/s]
# Epoch 47|Loss: 0.004890274605713785
# CREATE MemoryBank: 4
# 4it [00:01,  3.71it/s]
# 4it [00:03,  1.15it/s]
# Epoch 48|Loss: 0.005022262630518526
# CREATE MemoryBank: 4
# 4it [00:00,  6.01it/s]
# 4it [00:02,  1.57it/s]
# Epoch 49|Loss: 0.006977076176553965
# CREATE MemoryBank: 4
# 4it [00:00,  5.86it/s]
# quantum 4 0.5 FashionMNIST 0 1 1
# 12000
# tensor(0.2054, device='cuda:0')
# tensor(0.4066, device='cuda:0')
# tensor(0.5919, device='cuda:0')
# quantum 4 0.5 FashionMNIST 0 1 2
# 6000
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.4057, device='cuda:0')
# tensor(0.5938, device='cuda:0')
# quantum 4 0.5 FashionMNIST 0 1 5
# 2400
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5763, device='cuda:0')
# quantum 4 0.5 FashionMNIST 0 1 10
# 1200
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5792, device='cuda:0')
# quantum 8 0.5 FashionMNIST 0 1
# CREATE MemoryBank: 4
# 4it [00:01,  3.36it/s]
# 4it [00:04,  1.05s/it]
# Epoch 0|Loss: 0.009761281311511993
# CREATE MemoryBank: 4
# 4it [00:00,  4.78it/s]
# 4it [00:03,  1.25it/s]
# Epoch 1|Loss: 0.007239266647957265
# CREATE MemoryBank: 4
# 4it [00:00,  5.04it/s]
# 4it [00:03,  1.23it/s]
# Epoch 2|Loss: 0.006655034725554287
# CREATE MemoryBank: 4
# 4it [00:01,  3.56it/s]
# 4it [00:04,  1.13s/it]
# Epoch 3|Loss: 0.006150264875032008
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:03,  1.27it/s]
# Epoch 4|Loss: 0.009664661018177867
# CREATE MemoryBank: 4
# 4it [00:00,  5.23it/s]
# 4it [00:03,  1.26it/s]
# Epoch 5|Loss: 0.009396661072969437
# CREATE MemoryBank: 4
# 4it [00:00,  5.19it/s]
# 4it [00:04,  1.12s/it]
# Epoch 6|Loss: 0.009610174922272563
# CREATE MemoryBank: 4
# 4it [00:00,  4.57it/s]
# 4it [00:03,  1.25it/s]
# Epoch 7|Loss: 0.008500454481691122
# CREATE MemoryBank: 4
# 4it [00:00,  5.01it/s]
# 4it [00:03,  1.27it/s]
# Epoch 8|Loss: 0.008030458469875157
# CREATE MemoryBank: 4
# 4it [00:00,  5.03it/s]
# 4it [00:04,  1.08s/it]
# Epoch 9|Loss: 0.007490235613659024
# CREATE MemoryBank: 4
# 4it [00:00,  4.26it/s]
# 4it [00:03,  1.26it/s]
# Epoch 10|Loss: 0.010232786880806088
# CREATE MemoryBank: 4
# 4it [00:00,  5.19it/s]
# 4it [00:03,  1.26it/s]
# Epoch 11|Loss: 0.0075675074476748705
# CREATE MemoryBank: 4
# 4it [00:00,  5.19it/s]
# 4it [00:04,  1.02s/it]
# Epoch 12|Loss: 0.009119915775954723
# CREATE MemoryBank: 4
# 4it [00:01,  3.96it/s]
# 4it [00:03,  1.26it/s]
# Epoch 13|Loss: 0.01038291840814054
# CREATE MemoryBank: 4
# 4it [00:00,  5.02it/s]
# 4it [00:03,  1.26it/s]
# Epoch 14|Loss: 0.007752560428343713
# CREATE MemoryBank: 4
# 4it [00:00,  5.05it/s]
# 4it [00:04,  1.05s/it]
# Epoch 15|Loss: 0.007895039627328515
# CREATE MemoryBank: 4
# 4it [00:01,  3.24it/s]
# 4it [00:03,  1.22it/s]
# Epoch 16|Loss: 0.006982708000577986
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:03,  1.27it/s]
# Epoch 17|Loss: 0.0070458889240399
# CREATE MemoryBank: 4
# 4it [00:00,  4.97it/s]
# 4it [00:03,  1.05it/s]
# Epoch 18|Loss: 0.007536085671745241
# CREATE MemoryBank: 4
# 4it [00:01,  3.13it/s]
# 4it [00:03,  1.18it/s]
# Epoch 19|Loss: 0.006800538278184831
# CREATE MemoryBank: 4
# 4it [00:00,  5.01it/s]
# 4it [00:03,  1.23it/s]
# Epoch 20|Loss: 0.009327560546807945
# CREATE MemoryBank: 4
# 4it [00:00,  5.07it/s]
# 4it [00:03,  1.07it/s]
# Epoch 21|Loss: 0.006926470436155796
# CREATE MemoryBank: 4
# 4it [00:01,  3.30it/s]
# 4it [00:03,  1.08it/s]
# Epoch 22|Loss: 0.007041347911581397
# CREATE MemoryBank: 4
# 4it [00:00,  5.12it/s]
# 4it [00:03,  1.25it/s]
# Epoch 23|Loss: 0.006970853195525706
# CREATE MemoryBank: 4
# 4it [00:00,  4.91it/s]
# 4it [00:03,  1.07it/s]
# Epoch 24|Loss: 0.007866795174777508
# CREATE MemoryBank: 4
# 4it [00:01,  3.32it/s]
# 4it [00:04,  1.00s/it]
# Epoch 25|Loss: 0.007307752501219511
# CREATE MemoryBank: 4
# 4it [00:00,  5.03it/s]
# 4it [00:03,  1.27it/s]
# Epoch 26|Loss: 0.007458270061761141
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:03,  1.21it/s]
# Epoch 27|Loss: 0.006591071956790984
# CREATE MemoryBank: 4
# 4it [00:01,  3.47it/s]
# 4it [00:04,  1.03s/it]
# Epoch 28|Loss: 0.00595743942540139
# CREATE MemoryBank: 4
# 4it [00:00,  5.18it/s]
# 4it [00:03,  1.29it/s]
# Epoch 29|Loss: 0.004753378219902515
# CREATE MemoryBank: 4
# 4it [00:00,  5.33it/s]
# 4it [00:03,  1.32it/s]
# Epoch 30|Loss: 0.004905489971861243
# CREATE MemoryBank: 4
# 4it [00:00,  4.85it/s]
# 4it [00:04,  1.13s/it]
# Epoch 31|Loss: 0.00709187111351639
# CREATE MemoryBank: 4
# 4it [00:00,  4.91it/s]
# 4it [00:03,  1.25it/s]
# Epoch 32|Loss: 0.005260382895357907
# CREATE MemoryBank: 4
# 4it [00:00,  5.02it/s]
# 4it [00:03,  1.24it/s]
# Epoch 33|Loss: 0.0077907872619107366
# CREATE MemoryBank: 4
# 4it [00:00,  5.33it/s]
# 4it [00:04,  1.07s/it]
# Epoch 34|Loss: 0.00626734783872962
# CREATE MemoryBank: 4
# 4it [00:00,  4.30it/s]
# 4it [00:03,  1.31it/s]
# Epoch 35|Loss: 0.007970051490701735
# CREATE MemoryBank: 4
# 4it [00:00,  5.28it/s]
# 4it [00:03,  1.31it/s]
# Epoch 36|Loss: 0.006378547288477421
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.06it/s]
# Epoch 37|Loss: 0.00553359161131084
# CREATE MemoryBank: 4
# 4it [00:01,  3.12it/s]
# 4it [00:03,  1.25it/s]
# Epoch 38|Loss: 0.007799224113114178
# CREATE MemoryBank: 4
# 4it [00:00,  5.44it/s]
# 4it [00:03,  1.32it/s]
# Epoch 39|Loss: 0.005372386192902923
# CREATE MemoryBank: 4
# 4it [00:00,  5.34it/s]
# 4it [00:03,  1.17it/s]
# Epoch 40|Loss: 0.005378773203119636
# CREATE MemoryBank: 4
# 4it [00:01,  3.69it/s]
# 4it [00:03,  1.04it/s]
# Epoch 41|Loss: 0.005914233275689185
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.28it/s]
# Epoch 42|Loss: 0.007191142649389803
# CREATE MemoryBank: 4
# 4it [00:00,  5.28it/s]
# 4it [00:03,  1.31it/s]
# Epoch 43|Loss: 0.006981789134442806
# CREATE MemoryBank: 4
# 4it [00:00,  4.10it/s]
# 4it [00:04,  1.09s/it]
# Epoch 44|Loss: 0.006601295666769147
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:03,  1.31it/s]
# Epoch 45|Loss: 0.0057980354176834226
# CREATE MemoryBank: 4
# 4it [00:00,  5.10it/s]
# 4it [00:03,  1.31it/s]
# Epoch 46|Loss: 0.007292699767276645
# CREATE MemoryBank: 4
# 4it [00:00,  5.19it/s]
# 4it [00:04,  1.07s/it]
# Epoch 47|Loss: 0.005286867031827569
# CREATE MemoryBank: 4
# 4it [00:00,  4.45it/s]
# 4it [00:03,  1.28it/s]
# Epoch 48|Loss: 0.00630910589825362
# CREATE MemoryBank: 4
# 4it [00:00,  5.44it/s]
# 4it [00:03,  1.30it/s]
# Epoch 49|Loss: 0.006752044544555247
# CREATE MemoryBank: 4
# 4it [00:00,  5.33it/s]
# quantum 8 0.5 FashionMNIST 0 1 1
# 12000
# tensor(0.1254, device='cuda:0')
# tensor(0.2466, device='cuda:0')
# tensor(0.3607, device='cuda:0')
# quantum 8 0.5 FashionMNIST 0 1 2
# 6000
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.2483, device='cuda:0')
# tensor(0.3632, device='cuda:0')
# quantum 8 0.5 FashionMNIST 0 1 5
# 2400
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...
# 1200
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5317, device='cuda:0')
# quantum 8 0.5 KMNIST 0 1
# CREATE MemoryBank: 4
# 4it [00:00,  5.13it/s]
# 4it [00:03,  1.33it/s]
# Epoch 0|Loss: 0.012847786420024931
# CREATE MemoryBank: 4
# 4it [00:00,  5.35it/s]
# 4it [00:03,  1.18it/s]
# Epoch 1|Loss: 0.0137286433018744
# CREATE MemoryBank: 4
# 4it [00:01,  3.72it/s]
# 4it [00:03,  1.06it/s]
# Epoch 2|Loss: 0.010278624948114157
# CREATE MemoryBank: 4
# 4it [00:00,  5.17it/s]
# 4it [00:03,  1.29it/s]
# Epoch 3|Loss: 0.021900902967900038
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.32it/s]
# Epoch 4|Loss: 0.015647192485630512
# CREATE MemoryBank: 4
# 4it [00:00,  4.08it/s]
# 4it [00:04,  1.09s/it]
# Epoch 5|Loss: 0.015124280704185367
# CREATE MemoryBank: 4
# 4it [00:00,  5.37it/s]
# 4it [00:02,  1.34it/s]
# Epoch 6|Loss: 0.014767265180125833
# CREATE MemoryBank: 4
# 4it [00:00,  5.36it/s]
# 4it [00:03,  1.31it/s]
# Epoch 7|Loss: 0.013909068889915943
# CREATE MemoryBank: 4
# 4it [00:00,  5.39it/s]
# 4it [00:04,  1.01s/it]
# Epoch 8|Loss: 0.014267043909057975
# CREATE MemoryBank: 4
# 4it [00:00,  4.12it/s]
# 4it [00:02,  1.33it/s]
# Epoch 9|Loss: 0.014373485697433352
# CREATE MemoryBank: 4
# 4it [00:00,  5.24it/s]
# 4it [00:03,  1.32it/s]
# Epoch 10|Loss: 0.01701744692400098
# CREATE MemoryBank: 4
# 4it [00:00,  5.35it/s]
# 4it [00:03,  1.11it/s]
# Epoch 11|Loss: 0.020722619257867336
# CREATE MemoryBank: 4
# 4it [00:01,  3.62it/s]
# 4it [00:03,  1.28it/s]
# Epoch 12|Loss: 0.014694668585434556
# CREATE MemoryBank: 4
# 4it [00:00,  5.14it/s]
# 4it [00:03,  1.32it/s]
# Epoch 13|Loss: 0.015205486677587032
# CREATE MemoryBank: 4
# 4it [00:00,  5.00it/s]
# 4it [00:03,  1.19it/s]
# Epoch 14|Loss: 0.014680815394967794
# CREATE MemoryBank: 4
# 4it [00:01,  3.55it/s]
# 4it [00:03,  1.03it/s]
# Epoch 15|Loss: 0.014851455111056566
# CREATE MemoryBank: 4
# 4it [00:00,  5.16it/s]
# 4it [00:03,  1.31it/s]
# Epoch 16|Loss: 0.013575567165389657
# CREATE MemoryBank: 4
# 4it [00:00,  4.68it/s]
# 4it [00:03,  1.30it/s]
# Epoch 17|Loss: 0.01775684580206871
# CREATE MemoryBank: 4
# 4it [00:01,  3.68it/s]
# 4it [00:04,  1.07s/it]
# Epoch 18|Loss: 0.015409245621412992
# CREATE MemoryBank: 4
# 4it [00:00,  5.26it/s]
# 4it [00:03,  1.31it/s]
# Epoch 19|Loss: 0.013888777000829577
# CREATE MemoryBank: 4
# 4it [00:00,  5.34it/s]
# 4it [00:03,  1.30it/s]
# Epoch 20|Loss: 0.013831604039296508
# CREATE MemoryBank: 4
# 4it [00:00,  5.38it/s]
# 4it [00:04,  1.01s/it]
# Epoch 21|Loss: 0.014141022926196456
# CREATE MemoryBank: 4
# 4it [00:00,  4.74it/s]
# 4it [00:03,  1.30it/s]
# Epoch 22|Loss: 0.01398100983351469
# CREATE MemoryBank: 4
# 4it [00:00,  5.30it/s]
# 4it [00:03,  1.30it/s]
# Epoch 23|Loss: 0.012725126231089234
# CREATE MemoryBank: 4
# 4it [00:00,  5.19it/s]
# 4it [00:03,  1.04it/s]
# Epoch 24|Loss: 0.011974631808698177
# CREATE MemoryBank: 4
# 4it [00:01,  3.33it/s]
# 4it [00:03,  1.31it/s]
# Epoch 25|Loss: 0.012195108458399773
# CREATE MemoryBank: 4
# 4it [00:00,  5.33it/s]
# 4it [00:03,  1.33it/s]
# Epoch 26|Loss: 0.011076262220740318
# CREATE MemoryBank: 4
# 4it [00:00,  5.40it/s]
# 4it [00:03,  1.17it/s]
# Epoch 27|Loss: 0.011863991618156433
# CREATE MemoryBank: 4
# 4it [00:01,  3.48it/s]
# 4it [00:03,  1.05it/s]
# Epoch 28|Loss: 0.015167902689427137
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.32it/s]
# Epoch 29|Loss: 0.010132533963769674
# CREATE MemoryBank: 4
# 4it [00:00,  5.17it/s]
# 4it [00:03,  1.29it/s]
# Epoch 30|Loss: 0.010135455755516887
# CREATE MemoryBank: 4
# 4it [00:00,  4.19it/s]
# 4it [00:04,  1.10s/it]
# Epoch 31|Loss: 0.009328476851806045
# CREATE MemoryBank: 4
# 4it [00:00,  5.15it/s]
# 4it [00:03,  1.31it/s]
# Epoch 32|Loss: 0.01070294831879437
# CREATE MemoryBank: 4
# 4it [00:00,  5.23it/s]
# 4it [00:02,  1.34it/s]
# Epoch 33|Loss: 0.0107108389493078
# CREATE MemoryBank: 4
# 4it [00:00,  5.27it/s]
# 4it [00:04,  1.01s/it]
# Epoch 34|Loss: 0.009593985974788666
# CREATE MemoryBank: 4
# 4it [00:00,  4.44it/s]
# 4it [00:03,  1.32it/s]
# Epoch 35|Loss: 0.011218448169529438
# CREATE MemoryBank: 4
# 4it [00:00,  5.35it/s]
# 4it [00:03,  1.30it/s]
# Epoch 36|Loss: 0.009959796909242868
# CREATE MemoryBank: 4
# 4it [00:00,  5.24it/s]
# 4it [00:03,  1.06it/s]
# Epoch 37|Loss: 0.012736791744828224
# CREATE MemoryBank: 4
# 4it [00:01,  3.37it/s]
# 4it [00:03,  1.25it/s]
# Epoch 38|Loss: 0.010195550508797169
# CREATE MemoryBank: 4
# 4it [00:00,  5.22it/s]
# 4it [00:03,  1.32it/s]
# Epoch 39|Loss: 0.009779924992471933
# CREATE MemoryBank: 4
# 4it [00:00,  5.36it/s]
# 4it [00:03,  1.19it/s]
# Epoch 40|Loss: 0.009635342052206397
# CREATE MemoryBank: 4
# 4it [00:01,  3.69it/s]
# 4it [00:03,  1.05it/s]
# Epoch 41|Loss: 0.011137328576296568
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.32it/s]
# Epoch 42|Loss: 0.011091225547716022
# CREATE MemoryBank: 4
# 4it [00:00,  5.23it/s]
# 4it [00:03,  1.33it/s]
# Epoch 43|Loss: 0.010485204169526696
# CREATE MemoryBank: 4
# 4it [00:00,  4.15it/s]
# 4it [00:04,  1.12s/it]
# Epoch 44|Loss: 0.010086033260449767
# CREATE MemoryBank: 4
# 4it [00:00,  5.25it/s]
# 4it [00:03,  1.32it/s]
# Epoch 45|Loss: 0.0107774892821908
# CREATE MemoryBank: 4
# 4it [00:00,  5.28it/s]
# 4it [00:03,  1.32it/s]
# Epoch 46|Loss: 0.010221689473837614
# CREATE MemoryBank: 4
# 4it [00:00,  5.11it/s]
# 4it [00:04,  1.05s/it]
# Epoch 47|Loss: 0.009868108434602618
# CREATE MemoryBank: 4
# 4it [00:00,  4.68it/s]
# 4it [00:03,  1.31it/s]
# Epoch 48|Loss: 0.009627486811950803
# CREATE MemoryBank: 4
# 4it [00:00,  5.28it/s]
# 4it [00:03,  1.32it/s]
# Epoch 49|Loss: 0.013349143322557211
# CREATE MemoryBank: 4
# 4it [00:00,  5.18it/s]
# quantum 8 0.5 KMNIST 0 1 1
# 12000
# tensor(0.1922, device='cuda:0')
# tensor(0.3834, device='cuda:0')
# tensor(0.5577, device='cuda:0')
# quantum 8 0.5 KMNIST 0 1 2
# 6000
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.3873, device='cuda:0')
# tensor(0.5620, device='cuda:0')
# quantum 8 0.5 KMNIST 0 1 5
# 2400
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5504, device='cuda:0')
# quantum 8 0.5 KMNIST 0 1 10
# 1200
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.5275, device='cuda:0')
# quantum 16 0.5 KMNIST 0 1
# CREATE MemoryBank: 4
# 4it [00:00,  4.20it/s]
# 4it [00:04,  1.04s/it]
# Epoch 0|Loss: 0.04466085787862539
# CREATE MemoryBank: 4
# 4it [00:00,  4.35it/s]
# 4it [00:04,  1.21s/it]
# Epoch 1|Loss: 0.01786082750186324
# CREATE MemoryBank: 4
# 4it [00:01,  2.59it/s]
# 4it [00:04,  1.15s/it]
# Epoch 2|Loss: 0.009744129376485944
# CREATE MemoryBank: 4
# 4it [00:00,  4.22it/s]
# 4it [00:04,  1.05s/it]
# Epoch 3|Loss: 0.011414029402658343
# CREATE MemoryBank: 4
# 4it [00:01,  3.09it/s]
# 4it [00:05,  1.34s/it]
# Epoch 4|Loss: 0.012214768910780549
# CREATE MemoryBank: 4
# 4it [00:00,  4.11it/s]
# 4it [00:04,  1.05s/it]
# Epoch 5|Loss: 0.012208704138174653
# CREATE MemoryBank: 4
# 4it [00:00,  4.16it/s]
# 4it [00:05,  1.34s/it]
# Epoch 6|Loss: 0.010584293166175485
# CREATE MemoryBank: 4
# 4it [00:01,  3.70it/s]
# 4it [00:04,  1.04s/it]
# Epoch 7|Loss: 0.0102145045530051
# CREATE MemoryBank: 4
# 4it [00:00,  4.09it/s]
# 4it [00:04,  1.08s/it]
# Epoch 8|Loss: 0.008244618074968457
# CREATE MemoryBank: 4
# 4it [00:01,  2.82it/s]
# 4it [00:05,  1.31s/it]
# Epoch 9|Loss: 0.00889865355566144
# CREATE MemoryBank: 4
# 4it [00:00,  4.15it/s]
# 4it [00:04,  1.04s/it]
# Epoch 10|Loss: 0.00929838395677507
# CREATE MemoryBank: 4
# 4it [00:00,  4.32it/s]
# 4it [00:05,  1.38s/it]
# Epoch 11|Loss: 0.009548666886985302
# CREATE MemoryBank: 4
# 4it [00:01,  3.80it/s]
# 4it [00:04,  1.04s/it]
# Epoch 12|Loss: 0.008081726031377912
# CREATE MemoryBank: 4
# 4it [00:00,  4.18it/s]
# 4it [00:04,  1.06s/it]
# Epoch 13|Loss: 0.010702799656428397
# CREATE MemoryBank: 4
# 4it [00:01,  2.82it/s]
# 4it [00:05,  1.34s/it]
# Epoch 14|Loss: 0.00872379238717258
# CREATE MemoryBank: 4
# 4it [00:00,  4.12it/s]
# 4it [00:04,  1.03s/it]
# Epoch 15|Loss: 0.012200425378978252
# CREATE MemoryBank: 4
# 4it [00:00,  4.19it/s]
# 4it [00:05,  1.39s/it]
# Epoch 16|Loss: 0.008476130198687315
# CREATE MemoryBank: 4
# 4it [00:01,  3.65it/s]
# 4it [00:04,  1.02s/it]
# Epoch 17|Loss: 0.00718647672329098
# CREATE MemoryBank: 4
# 4it [00:00,  4.18it/s]
# 4it [00:04,  1.07s/it]
# Epoch 18|Loss: 0.008740002172999084
# CREATE MemoryBank: 4
# 4it [00:01,  2.71it/s]
# 4it [00:05,  1.33s/it]
# Epoch 19|Loss: 0.008684687898494303
# CREATE MemoryBank: 4
# 4it [00:01,  3.94it/s]
# 4it [00:04,  1.04s/it]
# Epoch 20|Loss: 0.007610139204189181
# CREATE MemoryBank: 4
# 4it [00:00,  4.09it/s]
# 4it [00:05,  1.39s/it]
# Epoch 21|Loss: 0.007790830917656422
# CREATE MemoryBank: 4
# 4it [00:00,  4.05it/s]
# 4it [00:04,  1.04s/it]
# Epoch 22|Loss: 0.006641469430178404
# CREATE MemoryBank: 4
# 4it [00:00,  4.25it/s]
# 4it [00:04,  1.11s/it]
# Epoch 23|Loss: 0.007384057040326297
# CREATE MemoryBank: 4
# 4it [00:01,  3.09it/s]
# 4it [00:05,  1.26s/it]
# Epoch 24|Loss: 0.006985899992287159
# CREATE MemoryBank: 4
# 4it [00:00,  4.04it/s]
# 4it [00:04,  1.04s/it]
# Epoch 25|Loss: 0.007976848748512566
# CREATE MemoryBank: 4
# 4it [00:00,  4.24it/s]
# 4it [00:05,  1.40s/it]
# Epoch 26|Loss: 0.00836089625954628
# CREATE MemoryBank: 4
# 4it [00:00,  4.26it/s]
# 4it [00:04,  1.04s/it]
# Epoch 27|Loss: 0.007782808504998684
# CREATE MemoryBank: 4
# 4it [00:00,  4.11it/s]
# 4it [00:05,  1.41s/it]
# Epoch 28|Loss: 0.00930499704554677
# CREATE MemoryBank: 4
# 4it [00:01,  2.80it/s]
# 4it [00:04,  1.06s/it]
# Epoch 29|Loss: 0.007049752282910049
# CREATE MemoryBank: 4
# 4it [00:00,  4.21it/s]
# 4it [00:04,  1.05s/it]
# Epoch 30|Loss: 0.007539905491285026
# CREATE MemoryBank: 4
# 4it [00:01,  3.62it/s]
# 4it [00:05,  1.39s/it]
# Epoch 31|Loss: 0.008124744286760688
# CREATE MemoryBank: 4
# 4it [00:00,  4.33it/s]
# 4it [00:04,  1.04s/it]
# Epoch 32|Loss: 0.010617977241054177
# CREATE MemoryBank: 4
# 4it [00:00,  4.21it/s]
# 4it [00:04,  1.24s/it]
# Epoch 33|Loss: 0.006762280943803489
# CREATE MemoryBank: 4
# 4it [00:01,  3.27it/s]
# 4it [00:04,  1.05s/it]
# Epoch 34|Loss: 0.006539048277772963
# CREATE MemoryBank: 4
# 4it [00:00,  4.06it/s]
# 4it [00:04,  1.08s/it]
# Epoch 35|Loss: 0.009045499027706683
# CREATE MemoryBank: 4
# 4it [00:01,  2.90it/s]
# 4it [00:05,  1.31s/it]
# Epoch 36|Loss: 0.007677795249037445
# CREATE MemoryBank: 4
# 4it [00:00,  4.13it/s]
# 4it [00:04,  1.02s/it]
# Epoch 37|Loss: 0.008278575842268765
# CREATE MemoryBank: 4
# 4it [00:00,  4.18it/s]
# 4it [00:05,  1.34s/it]
# Epoch 38|Loss: 0.006170029868371785
# CREATE MemoryBank: 4
# 4it [00:01,  3.93it/s]
# 4it [00:04,  1.04s/it]
# Epoch 39|Loss: 0.00802704889792949
# CREATE MemoryBank: 4
# 4it [00:00,  4.25it/s]
# 4it [00:04,  1.12s/it]
# Epoch 40|Loss: 0.006989968009293079
# CREATE MemoryBank: 4
# 4it [00:01,  2.99it/s]
# 4it [00:05,  1.26s/it]
# Epoch 41|Loss: 0.008733733789995313
# CREATE MemoryBank: 4
# 4it [00:00,  4.19it/s]
# 4it [00:04,  1.04s/it]
# Epoch 42|Loss: 0.006895410246215761
# CREATE MemoryBank: 4
# 4it [00:00,  4.23it/s]
# 4it [00:05,  1.38s/it]
# Epoch 43|Loss: 0.007323110126890242
# CREATE MemoryBank: 4
# 4it [00:01,  3.74it/s]
# 4it [00:04,  1.03s/it]
# Epoch 44|Loss: 0.007580791600048542
# CREATE MemoryBank: 4
# 4it [00:00,  4.09it/s]
# 4it [00:04,  1.09s/it]
# Epoch 45|Loss: 0.008811256615445018
# CREATE MemoryBank: 4
# 4it [00:01,  2.90it/s]
# 4it [00:05,  1.28s/it]
# Epoch 46|Loss: 0.006888875737786293
# CREATE MemoryBank: 4
# 4it [00:00,  4.23it/s]
# 4it [00:04,  1.03s/it]
# Epoch 47|Loss: 0.008035966195166111
# CREATE MemoryBank: 4
# 4it [00:00,  4.27it/s]
# 4it [00:05,  1.36s/it]
# Epoch 48|Loss: 0.006859433371573687
# CREATE MemoryBank: 4
# 4it [00:01,  3.71it/s]
# 4it [00:04,  1.04s/it]
# Epoch 49|Loss: 0.008991683600470424
# CREATE MemoryBank: 4
# 4it [00:00,  4.28it/s]
# quantum 16 0.5 KMNIST 0 1 1
# 12000
# tensor(0.1653, device='cuda:0')
# tensor(0.3350, device='cuda:0')
# tensor(0.4919, device='cuda:0')
# quantum 16 0.5 KMNIST 0 1 2
# 6000
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.3418, device='cuda:0')
# tensor(0.5015, device='cuda:0')
# quantum 16 0.5 KMNIST 0 1 5
# 2400
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.4946, device='cuda:0')
# quantum 16 0.5 KMNIST 0 1 10
# 1200
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# tensor(0.4717, device='cuda:0')
# quantum 2 0.5 MNIST 0 1
# CREATE MemoryBank: 5
# 5it [00:00,  5.70it/s]
# 5it [00:02,  2.10it/s]
# Epoch 0|Loss: 0.005945954890921712
# CREATE MemoryBank: 5
# 5it [00:00,  7.93it/s]
# 5it [00:02,  2.07it/s]
# Epoch 1|Loss: 0.007229082845151424
# CREATE MemoryBank: 5
# 5it [00:00,  7.65it/s]
# 5it [00:02,  2.09it/s]
# Epoch 2|Loss: 0.008436121791601182
# CREATE MemoryBank: 5
# 5it [00:00,  7.72it/s]
# 5it [00:03,  1.38it/s]
# Epoch 3|Loss: 0.008786807581782342
# CREATE MemoryBank: 5
# 5it [00:00,  6.42it/s]
# 5it [00:02,  2.10it/s]
# Epoch 4|Loss: 0.009420990012586117
# CREATE MemoryBank: 5
# 5it [00:00,  7.59it/s]
# 5it [00:02,  2.07it/s]
# Epoch 5|Loss: 0.011230042017996312
# CREATE MemoryBank: 5
# 5it [00:00,  7.61it/s]
# 5it [00:02,  2.04it/s]
# Epoch 6|Loss: 0.011742803826928138
# CREATE MemoryBank: 5
# 5it [00:00,  6.41it/s]
# 5it [00:03,  1.38it/s]
# Epoch 7|Loss: 0.01379058212041855
# CREATE MemoryBank: 5
# 5it [00:00,  6.17it/s]
# 5it [00:02,  2.09it/s]
# Epoch 8|Loss: 0.01088562309741974
# CREATE MemoryBank: 5
# 5it [00:00,  7.64it/s]
# 5it [00:02,  2.09it/s]
# Epoch 9|Loss: 0.010582271404564381
# CREATE MemoryBank: 5
# 5it [00:00,  7.47it/s]
# 5it [00:02,  2.07it/s]
# Epoch 10|Loss: 0.012573669105768204
# CREATE MemoryBank: 5
# 5it [00:00,  6.77it/s]
# 5it [00:03,  1.39it/s]
# Epoch 11|Loss: 0.01174287274479866
# CREATE MemoryBank: 5
# 5it [00:00,  6.43it/s]
# 5it [00:02,  2.08it/s]
# Epoch 12|Loss: 0.013010167330503464
# CREATE MemoryBank: 5
# 5it [00:00,  7.60it/s]
# 5it [00:02,  2.07it/s]
# Epoch 13|Loss: 0.01342088971287012
# CREATE MemoryBank: 5
# 5it [00:00,  7.37it/s]
# 5it [00:02,  2.04it/s]
# Epoch 14|Loss: 0.01602593418210745
# CREATE MemoryBank: 5
# 5it [00:00,  6.30it/s]
# 5it [00:03,  1.34it/s]
# Epoch 15|Loss: 0.013605589047074318
# CREATE MemoryBank: 5
# 5it [00:00,  6.52it/s]
# 5it [00:02,  2.06it/s]
# Epoch 16|Loss: 0.01408199556171894
# CREATE MemoryBank: 5
# 5it [00:00,  7.17it/s]
# 3it [00:01,  1.85it/s]
